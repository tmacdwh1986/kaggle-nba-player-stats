# %% [markdown]
# # Clean dataset
# Exploration of the Kaggle dataset [NBA Players stats since 1950](https://www.kaggle.com/drgilermo/nba-players-stats).

# %%
import pandas as pd
from numpy import floor

# %% [markdown]
# ## Load players dataset

# %%
players_df = pd.read_csv('../data/raw/Players.csv', header=0, index_col=0)
players_df.head()
# Out:
#              Player  height  weight                          collage    born  \
# id
# 0   Curly Armstrong   180.0    77.0               Indiana University  1918.0
# 1      Cliff Barker   188.0    83.0           University of Kentucky  1921.0
# 2     Leo Barnhorst   193.0    86.0         University of Notre Dame  1924.0
# 3        Ed Bartels   196.0    88.0  North Carolina State University  1925.0
# 4       Ralph Beard   178.0    79.0           University of Kentucky  1927.0
#
#      birth_city birth_state
# id
# 0           NaN         NaN
# 1      Yorktown     Indiana
# 2           NaN         NaN
# 3           NaN         NaN
# 4   Hardinsburg    Kentucky

# %%
players_df.describe()
# Out:
#             height       weight        born
# count  3921.000000  3921.000000  3921.00000
# mean    198.704922    94.783219  1962.37975
# std       9.269761    12.039515    20.33491
# min     160.000000    60.000000  1913.00000
# 25%     190.000000    86.000000  1948.00000
# 50%     198.000000    95.000000  1964.00000
# 75%     206.000000   102.000000  1979.00000
# max     231.000000   163.000000  1997.00000

# %%
players_df.isnull().sum()
# Out:
# Player           1
# height           1
# weight           1
# collage        349
# born             1
# birth_city     470
# birth_state    483
# dtype: int64

# %%
players_df.loc[players_df.isnull()['Player'],:]
# Out:
#     Player  height  weight collage  born birth_city birth_state
# id
# 223    NaN     NaN     NaN     NaN   NaN        NaN         NaN

# %% [markdown]
# There is one player whose values are all null, so we will remove this player.

# %%
players_df.drop(223, axis=0, inplace=True)

# %%
players_df.nunique()
# Out:
# Player         3921
# height           28
# weight           76
# collage         422
# born             84
# birth_city     1264
# birth_state     128
# dtype: int64

# %% [markdown]
# The player names are unique so we will use this as the index.

# %%
players_df.set_index('Player', inplace=True)
players_df.head()
# Out:
#                  height  weight                          collage    born  \
# Player
# Curly Armstrong   180.0    77.0               Indiana University  1918.0
# Cliff Barker      188.0    83.0           University of Kentucky  1921.0
# Leo Barnhorst     193.0    86.0         University of Notre Dame  1924.0
# Ed Bartels        196.0    88.0  North Carolina State University  1925.0
# Ralph Beard       178.0    79.0           University of Kentucky  1927.0
#
#                   birth_city birth_state
# Player
# Curly Armstrong          NaN         NaN
# Cliff Barker        Yorktown     Indiana
# Leo Barnhorst            NaN         NaN
# Ed Bartels               NaN         NaN
# Ralph Beard      Hardinsburg    Kentucky

# %% [markdown]
# ## Load season stats dataset

# %%
season_stats_df = pd.read_csv('../data/raw/Seasons_Stats.csv', header=0, index_col=0)
season_stats_df.head(20)
# Out:
#       Year           Player  Pos   Age   Tm     G  GS  MP  PER    TS%   ...    \
# id                                                                      ...
# 0   1950.0  Curly Armstrong  G-F  31.0  FTW  63.0 NaN NaN  NaN  0.368   ...
# 1   1950.0     Cliff Barker   SG  29.0  INO  49.0 NaN NaN  NaN  0.435   ...
# 2   1950.0    Leo Barnhorst   SF  25.0  CHS  67.0 NaN NaN  NaN  0.394   ...
# 3   1950.0       Ed Bartels    F  24.0  TOT  15.0 NaN NaN  NaN  0.312   ...
# 4   1950.0       Ed Bartels    F  24.0  DNN  13.0 NaN NaN  NaN  0.308   ...
# 5   1950.0       Ed Bartels    F  24.0  NYK   2.0 NaN NaN  NaN  0.376   ...
# 6   1950.0      Ralph Beard    G  22.0  INO  60.0 NaN NaN  NaN  0.422   ...
# 7   1950.0       Gene Berce  G-F  23.0  TRI   3.0 NaN NaN  NaN  0.275   ...
# 8   1950.0    Charlie Black  F-C  28.0  TOT  65.0 NaN NaN  NaN  0.346   ...
# 9   1950.0    Charlie Black  F-C  28.0  FTW  36.0 NaN NaN  NaN  0.362   ...
# 10  1950.0    Charlie Black  F-C  28.0  AND  29.0 NaN NaN  NaN  0.326   ...
# 11  1950.0      Nelson Bobb   PG  25.0  PHW  57.0 NaN NaN  NaN  0.396   ...
# 12  1950.0  Jake Bornheimer  F-C  22.0  PHW  60.0 NaN NaN  NaN  0.356   ...
# 13  1950.0     Vince Boryla   SF  22.0  NYK  59.0 NaN NaN  NaN  0.426   ...
# 14  1950.0        Don Boven  F-G  24.0  WAT  62.0 NaN NaN  NaN  0.461   ...
# 15  1950.0    Harry Boykoff    C  27.0  WAT  61.0 NaN NaN  NaN  0.479   ...
# 16  1950.0      Joe Bradley    G  21.0  CHS  46.0 NaN NaN  NaN  0.289   ...
# 17  1950.0      Bob Brannum   PF  24.0  SHE  59.0 NaN NaN  NaN  0.408   ...
# 18  1950.0       Carl Braun  G-F  22.0  NYK  67.0 NaN NaN  NaN  0.434   ...
# 19  1950.0    Frankie Brian    G  26.0  AND  64.0 NaN NaN  NaN  0.415   ...
#
#       FT%  ORB  DRB  TRB    AST  STL  BLK  TOV     PF     PTS
# id
# 0   0.705  NaN  NaN  NaN  176.0  NaN  NaN  NaN  217.0   458.0
# 1   0.708  NaN  NaN  NaN  109.0  NaN  NaN  NaN   99.0   279.0
# 2   0.698  NaN  NaN  NaN  140.0  NaN  NaN  NaN  192.0   438.0
# 3   0.559  NaN  NaN  NaN   20.0  NaN  NaN  NaN   29.0    63.0
# 4   0.548  NaN  NaN  NaN   20.0  NaN  NaN  NaN   27.0    59.0
# 5   0.667  NaN  NaN  NaN    0.0  NaN  NaN  NaN    2.0     4.0
# 6   0.762  NaN  NaN  NaN  233.0  NaN  NaN  NaN  132.0   895.0
# 7   0.000  NaN  NaN  NaN    2.0  NaN  NaN  NaN    6.0    10.0
# 8   0.651  NaN  NaN  NaN  163.0  NaN  NaN  NaN  273.0   661.0
# 9   0.632  NaN  NaN  NaN   75.0  NaN  NaN  NaN  140.0   382.0
# 10  0.688  NaN  NaN  NaN   88.0  NaN  NaN  NaN  133.0   279.0
# 11  0.626  NaN  NaN  NaN   46.0  NaN  NaN  NaN   97.0   242.0
# 12  0.667  NaN  NaN  NaN   40.0  NaN  NaN  NaN  111.0   254.0
# 13  0.764  NaN  NaN  NaN   95.0  NaN  NaN  NaN  203.0   612.0
# 14  0.688  NaN  NaN  NaN  137.0  NaN  NaN  NaN  255.0   656.0
# 15  0.775  NaN  NaN  NaN  149.0  NaN  NaN  NaN  229.0   779.0
# 16  0.395  NaN  NaN  NaN   36.0  NaN  NaN  NaN   51.0    87.0
# 17  0.690  NaN  NaN  NaN  205.0  NaN  NaN  NaN  279.0   713.0
# 18  0.762  NaN  NaN  NaN  247.0  NaN  NaN  NaN  188.0  1031.0
# 19  0.824  NaN  NaN  NaN  189.0  NaN  NaN  NaN  192.0  1138.0
#
# [20 rows x 52 columns]

# %%
season_stats_df.describe()
# Out:
#                Year           Age             G            GS            MP  \
# count  24624.000000  24616.000000  24624.000000  18233.000000  24138.000000
# mean    1992.594989     26.664405     50.837110     23.593375   1209.720317
# std       17.429594      3.841892     26.496161     28.632387    941.146575
# min     1950.000000     18.000000      1.000000      0.000000      0.000000
# 25%     1981.000000     24.000000     27.000000      0.000000    340.000000
# 50%     1996.000000     26.000000     58.000000      8.000000   1053.000000
# 75%     2007.000000     29.000000     75.000000     45.000000   1971.000000
# max     2017.000000     44.000000     88.000000     83.000000   3882.000000
#
#                 PER           TS%          3PAr           FTr          ORB%  \
# count  24101.000000  24538.000000  18839.000000  24525.000000  20792.000000
# mean      12.479071      0.493001      0.158604      0.325455      6.181565
# std        6.039014      0.094469      0.187495      0.218971      4.872685
# min      -90.600000      0.000000      0.000000      0.000000      0.000000
# 25%        9.800000      0.458000      0.005000      0.208000      2.600000
# 50%       12.700000      0.506000      0.064000      0.296000      5.400000
# 75%       15.600000      0.544000      0.288000      0.400000      9.000000
# max      129.100000      1.136000      1.000000      6.000000    100.000000
#
#            ...                FT%           ORB           DRB           TRB  \
# count      ...       23766.000000  20797.000000  20797.000000  24312.000000
# mean       ...           0.719279     62.189210    147.199404    224.637381
# std        ...           0.141824     67.324881    145.921912    228.190203
# min        ...           0.000000      0.000000      0.000000      0.000000
# 25%        ...           0.657000     12.000000     33.000000     51.000000
# 50%        ...           0.743000     38.000000    106.000000    159.000000
# 75%        ...           0.808000     91.000000    212.000000    322.000000
# max        ...           1.000000    587.000000   1111.000000   2149.000000
#
#                 AST           STL           BLK           TOV            PF  \
# count  24624.000000  20797.000000  20797.000000  19645.000000  24624.000000
# mean     114.852623     39.897052     24.470260     73.939832    116.339222
# std      135.863913     38.713053     36.935084     67.713803     84.791873
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%       19.000000      9.000000      3.000000     18.000000     39.000000
# 50%       68.000000     29.000000     11.000000     55.000000    109.000000
# 75%      160.000000     60.000000     29.000000    112.000000    182.000000
# max     1164.000000    301.000000    456.000000    464.000000    386.000000
#
#                 PTS
# count  24624.000000
# mean     510.116350
# std      492.922981
# min        0.000000
# 25%      106.000000
# 50%      364.000000
# 75%      778.000000
# max     4029.000000
#
# [8 rows x 49 columns]

# %% [markdown]
# There are several rows with all null values, so we will remove these.

# %%
season_stats_df.dropna(how='all', inplace=True)

# %%
season_stats_df.isnull().sum()
# Out:
# Year          0
# Player        0
# Pos           0
# Age           8
# Tm            0
# G             0
# GS         6391
# MP          486
# PER         523
# TS%          86
# 3PAr       5785
# FTr          99
# ORB%       3832
# DRB%       3832
# TRB%       3053
# AST%       2069
# STL%       3832
# BLK%       3832
# TOV%       5042
# USG%       4984
# blanl     24624
# OWS          39
# DWS          39
# WS           39
# WS/48       523
# blank2    24624
# OBPM       3827
# DBPM       3827
# BPM        3827
# VORP       3827
# FG            0
# FGA           0
# FG%          99
# 3P         5697
# 3PA        5697
# 3P%        9208
# 2P            0
# 2PA           0
# 2P%         128
# eFG%         99
# FT            0
# FTA           0
# FT%         858
# ORB        3827
# DRB        3827
# TRB         312
# AST           0
# STL        3827
# BLK        3827
# TOV        4979
# PF            0
# PTS           0
# dtype: int64

# %%
print('{no_rows} total rows'.format(no_rows=len(season_stats_df)))
print('{no_rows} unique combinations of Year, Player, Pos, and Tm'.format(no_rows=len(season_stats_df.groupby(['Year', 'Player', 'Pos', 'Tm']))))
# Out:
# 24624 total rows
# 24624 unique combinations of Year, Player, Pos, and Tm

# %% [markdown]
# Each row is a unique combination of year, player, position, and team.

# %% [markdown]
# ## Player decade
# We are only interested in player from 1970 onwards, so we will remove the rows we are not interested in. In addition, we are only interested in the decades in which each player played, so we will extract this information and add it to the players data frame.

# %%
season_stats_df = season_stats_df[season_stats_df['Year'] >= 1970]

# %%
decade_mapping = {
    70: '70s',
    80: '80s',
    90: '90s',
    0: '00s',
    10: '10s'
}

def extract_decade(years):
    decades = years.apply(lambda year: int(floor((year % 100) / 10) * 10)) \
                   .unique() \
                   .tolist()
            
    decades = list(map(lambda decade: decade_mapping[decade], decades))
    
    return decades

# %%
player_decades = season_stats_df.groupby('Player')['Year'].apply(extract_decade)
player_decades.name = 'decades'

players_df = pd.concat([players_df, player_decades], join='inner', axis=1)

# %%
players_df.head()
# Out:
#                 height  weight                      collage    born  \
# Player
# Freddie Lewis    188.0    88.0  Eastern Kentucky University  1921.0
# Bob Cousy*       185.0    79.0    College of the Holy Cross  1928.0
# Richie Guerin*   193.0    88.0                 Iona College  1932.0
# Jim Paxson       198.0    90.0         University of Dayton  1932.0
# Hot Rod          193.0    83.0                          NaN  1935.0
#
#                birth_city birth_state     decades
# Player
# Freddie Lewis    Brooklyn    New York       [70s]
# Bob Cousy*       New York    New York       [70s]
# Richie Guerin*   New York    New York       [70s]
# Jim Paxson      Pennville     Indiana  [80s, 90s]
# Hot Rod               NaN         NaN  [80s, 90s]

# %% [markdown]
# Note that we did an inner join, so the player now in the players data frame are only the players with records in both the players and season stats datasets.

# %% [markdown]
# ## Player positions
# There are five primary positions in basketball:
#
# * Point guard (PG)
# * Shooting guard (SG)
# * Small forward (SF)
# * Power forward (PF)
# * Centre (C)
#
# However, there are many different positions values in the dataset, all of which are combinations of the above five positions.

# %%
season_stats_df['Pos'].unique()
# Out:
# array(['PF', 'C', 'PG', 'SF', 'G', 'SG', 'SF-PF', 'F', 'G-F', 'PF-SF',
#        'F-C', 'SF-SG', 'C-F', 'SG-PG', 'C-PF', 'PF-C', 'SF-PG', 'C-SF',
#        'SG-SF', 'PG-SG', 'PG-SF', 'SG-PF'], dtype=object)

# %% [markdown]
# We will create a mapping from the positions in the dataset to the default five. Each player has potentially played in multiple positions throughout their career. For the puposes of choosing a dream team, we will say a player is eligible for a position if they have played there at least once.

# %%
position_mapping = {
    'G-F': ['PG', 'SG', 'SF', 'PF'],
    'F': ['SF', 'PF'],
    'G': ['PG', 'SG'],
    'F-C': ['SF', 'PF', 'C'],
    'F-G': ['PG', 'SG', 'SF', 'PF'],
    'C-F': ['SF', 'PF', 'C'],
    'PF-C': ['PF', 'C'],
    'SF-SG': ['SF', 'SG'],
    'C-PF': ['PF', 'C'],
    'SG-SF': ['SF', 'SG'],
    'PF-SF': ['PF', 'SF'],
    'SF-PF': ['SF', 'PF'],
    'SG-PG': ['SG', 'PG'],
    'SF-PG': ['SF', 'PG'],
    'C-SF': ['C', 'SF'],
    'PG-SG': ['PG', 'SG'],
    'PG-SF': ['PG', 'SF'],
    'SG-PF': ['SG', 'PF']
}

season_stats_df['Pos'] = season_stats_df['Pos'].apply(lambda pos: position_mapping[pos] if pos in position_mapping else [pos])

# %% [markdown]
# Next we will determine the positions each player has played and add that information to the players data frame.

# %%
players_df['positions'] = season_stats_df.groupby('Player')['Pos'].apply(lambda df: list(set([val for sublist in df.values for val in sublist])))

players_df.head()
# Out:
#                 height  weight                      collage    born  \
# Player
# Freddie Lewis    188.0    88.0  Eastern Kentucky University  1921.0
# Bob Cousy*       185.0    79.0    College of the Holy Cross  1928.0
# Richie Guerin*   193.0    88.0                 Iona College  1932.0
# Jim Paxson       198.0    90.0         University of Dayton  1932.0
# Hot Rod          193.0    83.0                          NaN  1935.0
#
#                birth_city birth_state     decades positions
# Player
# Freddie Lewis    Brooklyn    New York       [70s]      [PG]
# Bob Cousy*       New York    New York       [70s]      [PG]
# Richie Guerin*   New York    New York       [70s]      [SG]
# Jim Paxson      Pennville     Indiana  [80s, 90s]  [SG, PG]
# Hot Rod               NaN         NaN  [80s, 90s]   [PF, C]

# %% [markdown]
# Quick sanitiy check to ensure we only have the standard five positions.

# %%
print(set([position for sublist in players_df['positions'] for position in sublist]))
# Out:
# {'C', 'PF', 'PG', 'SG', 'SF'}

# %% [markdown]
# We do! Lets move on.

# %% [markdown]
# ## Available stats
# There are many columns in this dataset, whose meanings can be found [here](https://www.basketball-reference.com/about/glossary.html). In the first instance we will only consider stats available for all players when choosing our dream team. These are:
#
# | Code   | Description   |
# |:------ |:------------- |
# | G      | Games |
# | MP     | Minutes Played |
# | OWS    | Offensive Win Shares (see [calculating win shares](https://www.basketball-reference.com/about/ws.html) for more information) |
# | DWS    | Defensive Win Shares (see [calculating win shares](https://www.basketball-reference.com/about/ws.html) for more information) |
# | WS     | Win Shares; an estimate of the number of wins contributed by a player (see [calculating win shares](https://www.basketball-reference.com/about/ws.html) for more information) |
# | FG     | Field Goals (includes both 2-point field goals and 3-point field goals) |
# | FGA    | Field Goal Attempts (includes both 2-point field goal attempts and 3-point field goal attempts) |
# | 2P     | 2-Point Field Goals |
# | 2PA    | 2-Point Field Goal Attempts |
# | FT     | Free Throws |
# | FTA    | Free Throw Attempts
# | TRB    | Total Rebounds |
# | AST    | Assists |
# | PF     | Personal Fouls |
# | PTS    | Points |
#
# Notice that some incomplete columns can be calculated from the complete columns:
#
# * Field goal percentage (FG%) = FG / FGA.
# * 2-point field goal percentage (2P%) = 2P / 2PA.
# * 3-point field goals (3P) = FG - 2P.
# * 3-point field goal attempts (3PA) = FGA - 2PA.
# * 3-point field goal percentage (3P%) = 3P / 3PA.
# * Free throw percentage (FT%) = FT / FTA.
#
# Some other metrics potentially of interest are:
#
# * Assists per game (APG) = AST / G.
# * Points per game (PPG) = PTS / G.
# * Personal fouls per game (PFPG) = PF / G.
# * [Win shares per 48 minutes](https://www.basketball-reference.com/leaders/ws_per_48_career.html) (WS48) = 48 * WS / MP
#
# We will go ahead and caculate these metrics, but first lets drop the non-complete columns. In addition, we're not worried about the players' teams and ages, so we can also drop those columns. We have already calculated the decades each player played in, and their positions, so these columns can go also.

# %%
season_stats_df.dropna(how='any', axis=1, inplace=True)
season_stats_df.drop(['Year', 'Tm', 'Age', 'Pos'], inplace=True, axis=1)

season_stats_df.head()
# Out:
#                     Player     G      MP  OWS  DWS    WS     FG     FGA  \
# id
# 2867       Zaid Abdul-Aziz  80.0  1637.0  0.0  2.0   2.0  237.0   546.0
# 2868  Kareem Abdul-Jabbar*  82.0  3534.0  9.3  4.5  13.8  938.0  1810.0
# 2869          Rick Adelman  35.0   717.0 -0.2  0.9   0.7   96.0   247.0
# 2870          Lucius Allen  81.0  1817.0  1.2  1.0   2.2  306.0   692.0
# 2871      Wally Anderzunas  44.0   370.0 -0.4  0.3  -0.2   65.0   166.0
#
#          2P     2PA     FT    FTA     TRB    AST     PF     PTS
# id
# 2867  237.0   546.0  119.0  185.0   603.0   62.0  167.0   593.0
# 2868  938.0  1810.0  485.0  743.0  1190.0  337.0  283.0  2361.0
# 2869   96.0   247.0   68.0   91.0    81.0  113.0   90.0   260.0
# 2870  306.0   692.0  182.0  249.0   211.0  342.0  201.0   794.0
# 2871   65.0   166.0   29.0   46.0    82.0    9.0   47.0   159.0

# %% [markdown]
# We must now group by player, creating a per-player row where the column values are combined additively. We can then join this into the players data frame.

# %%
season_stats_by_player = season_stats_df.groupby('Player') \
                                        .apply(lambda df: df.iloc[:, 1:].sum())

# %%
players_df = pd.concat([players_df, season_stats_by_player], join='inner', axis=1)

players_df.head()
# Out:
#                 height  weight                      collage    born  \
# Player
# Freddie Lewis    188.0    88.0  Eastern Kentucky University  1921.0
# Bob Cousy*       185.0    79.0    College of the Holy Cross  1928.0
# Richie Guerin*   193.0    88.0                 Iona College  1932.0
# Jim Paxson       198.0    90.0         University of Dayton  1932.0
# Hot Rod          193.0    83.0                          NaN  1935.0
#
#                birth_city birth_state     decades positions      G       MP  \
# Player
# Freddie Lewis    Brooklyn    New York       [70s]      [PG]   32.0    552.0
# Bob Cousy*       New York    New York       [70s]      [PG]    7.0     34.0
# Richie Guerin*   New York    New York       [70s]      [SG]    8.0     64.0
# Jim Paxson      Pennville     Indiana  [80s, 90s]  [SG, PG]  829.0  22158.0
# Hot Rod               NaN         NaN  [80s, 90s]   [PF, C]  887.0  26327.0
#
#                  ...         FG     FGA      2P     2PA      FT     FTA  \
# Player           ...
# Freddie Lewis    ...       81.0   199.0    81.0   199.0    62.0    77.0
# Bob Cousy*       ...        1.0     3.0     1.0     3.0     3.0     3.0
# Richie Guerin*   ...        3.0    11.0     3.0    11.0     1.0     1.0
# Jim Paxson       ...     4682.0  9431.0  4579.0  8975.0  2079.0  2572.0
# Hot Rod          ...     3688.0  7681.0  3686.0  7662.0  2406.0  3315.0
#
#                    TRB     AST      PF      PTS
# Player
# Freddie Lewis     47.0    56.0    58.0    224.0
# Bob Cousy*         5.0    10.0    11.0      5.0
# Richie Guerin*     2.0    12.0     9.0      7.0
# Jim Paxson      1638.0  2376.0  1515.0  11546.0
# Hot Rod         5998.0  1592.0  2253.0   9784.0
#
# [5 rows x 23 columns]

# %% [markdown]
# One final cleaning step. If a player has played zero minutes they're unlikely to make the dream team, so lets drop these players.

# %%
players_df = players_df.loc[players_df['MP'] > 0, :]

# %% [markdown]
# We can now calculate the additional metrics discussed above.

# %%
players_df['FG%'] = players_df.loc[:, ['FG', 'FGA']].apply(lambda row: row['FG'] / row['FGA'] if row['FGA'] != 0 else 0, axis=1)
players_df['2P%'] = players_df.loc[:, ['2P', '2PA']].apply(lambda row: row['2P'] / row['2PA'] if row['2PA'] != 0 else 0, axis=1)
players_df['3P'] = players_df.loc[:, ['FG', '2P']].apply(lambda row: row['FG'] - row['2P'], axis=1)
players_df['3PA'] = players_df.loc[:, ['FGA', '2PA']].apply(lambda row: row['FGA'] - row['2PA'], axis=1)
players_df['3P%'] = players_df.loc[:, ['3P', '3PA']].apply(lambda row: row['3P'] / row['3PA'] if row['3PA'] != 0 else 0, axis=1)
players_df['FT%'] = players_df.loc[:, ['FT', 'FTA']].apply(lambda row: row['FT'] / row['FTA'] if row['FTA'] != 0 else 0, axis=1)
players_df['APG'] = players_df.loc[:, ['AST', 'G']].apply(lambda row: row['AST'] / row['G'] if row['G'] != 0 else 0, axis=1)
players_df['PPG'] = players_df.loc[:, ['PTS', 'G']].apply(lambda row: row['PTS'] / row['G'] if row['G'] != 0 else 0, axis=1)
players_df['PFPG'] = players_df.loc[:, ['PF', 'G']].apply(lambda row: row['PF'] / row['G'] if row['G'] != 0 else 0, axis=1)
players_df['WS48'] = players_df.loc[:, ['WS', 'MP']].apply(lambda row: 48 * row['WS'] / row['MP'], axis=1)

# %% [markdown]
# Furthermore, we only need to keep the relative metrics. For example, we only need FG%, not FG and FGA.

# %%
players_df.drop(['FG', 'FGA', '2P', '2PA', '3P', '3PA', 'FT', 'FTA', 'AST', 'PF', 'PTS'], axis=1, inplace=True)

players_df.head()
# Out:
#                 height  weight                      collage    born  \
# Player
# Freddie Lewis    188.0    88.0  Eastern Kentucky University  1921.0
# Bob Cousy*       185.0    79.0    College of the Holy Cross  1928.0
# Richie Guerin*   193.0    88.0                 Iona College  1932.0
# Jim Paxson       198.0    90.0         University of Dayton  1932.0
# Hot Rod          193.0    83.0                          NaN  1935.0
#
#                birth_city birth_state     decades positions      G       MP  \
# Player
# Freddie Lewis    Brooklyn    New York       [70s]      [PG]   32.0    552.0
# Bob Cousy*       New York    New York       [70s]      [PG]    7.0     34.0
# Richie Guerin*   New York    New York       [70s]      [SG]    8.0     64.0
# Jim Paxson      Pennville     Indiana  [80s, 90s]  [SG, PG]  829.0  22158.0
# Hot Rod               NaN         NaN  [80s, 90s]   [PF, C]  887.0  26327.0
#
#                   ...       WS     TRB       FG%       2P%       3P%  \
# Player            ...
# Freddie Lewis     ...      0.5    47.0  0.407035  0.407035  0.000000
# Bob Cousy*        ...      0.1     5.0  0.333333  0.333333  0.000000
# Richie Guerin*    ...     -0.1     2.0  0.272727  0.272727  0.000000
# Jim Paxson        ...     55.0  1638.0  0.496448  0.510195  0.225877
# Hot Rod           ...     70.6  5998.0  0.480146  0.481075  0.105263
#
#                      FT%       APG        PPG      PFPG      WS48
# Player
# Freddie Lewis   0.805195  1.750000   7.000000  1.812500  0.043478
# Bob Cousy*      1.000000  1.428571   0.714286  1.571429  0.141176
# Richie Guerin*  1.000000  1.500000   0.875000  1.125000 -0.075000
# Jim Paxson      0.808320  2.866104  13.927624  1.827503  0.119144
# Hot Rod         0.725792  1.794814  11.030440  2.540023  0.128720
#
# [5 rows x 22 columns]

# %% [markdown]
# Lets store this as an interim dataset for later use.

# %%
players_df.to_csv('../data/interim/player_data_cleaned.csv', header=True, index=True, sep=',')
